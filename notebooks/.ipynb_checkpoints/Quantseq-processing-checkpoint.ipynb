# %% [markdown]
# ### Download Illumina sequence fastq files from Owl

# %%
! bash ../scripts/download-quantseq.sh
# Out:
# --2018-11-14 17:36:03--  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/
# Resolving owl.fish.washington.edu (owl.fish.washington.edu)... 128.95.149.83
# Connecting to owl.fish.washington.edu (owl.fish.washington.edu)|128.95.149.83|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6748 (6.6K) [text/html]
# Saving to: ‘../data/illumina-raw/index.html.tmp’
#
# index.html.tmp      100%[===================>]   6.59K  --.-KB/s    in 0s
#
# 2018-11-14 17:36:04 (96.1 MB/s) - ‘../data/illumina-raw/index.html.tmp’ saved [6748/6748]
#
# Loading robots.txt; please ignore errors.
# --2018-11-14 17:36:04--  http://owl.fish.washington.edu/robots.txt
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 404 Not Found
# 2018-11-14 17:36:04 ERROR 404: Not Found.
#
# Removing ../data/illumina-raw/index.html.tmp since it should be rejected.
#
# --2018-11-14 17:36:04--  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/?C=N;O=D
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6748 (6.6K) [text/html]
# Saving to: ‘../data/illumina-raw/index.html?C=N;O=D.tmp’
#
# index.html?C=N;O=D. 100%[===================>]   6.59K  --.-KB/s    in 0s
#
# 2018-11-14 17:36:04 (230 MB/s) - ‘../data/illumina-raw/index.html?C=N;O=D.tmp’ saved [6748/6748]
#
# Removing ../data/illumina-raw/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2018-11-14 17:36:04--  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/?C=M;O=A
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6748 (6.6K) [text/html]
# Saving to: ‘../data/illumina-raw/index.html?C=M;O=A.tmp’
#
# index.html?C=M;O=A. 100%[===================>]   6.59K  --.-KB/s    in 0.002s
#
# 2018-11-14 17:36:04 (3.84 MB/s) - ‘../data/illumina-raw/index.html?C=M;O=A.tmp’ saved [6748/6748]
#
# Removing ../data/illumina-raw/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2018-11-14 17:36:04--  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/?C=S;O=A
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6748 (6.6K) [text/html]
# Saving to: ‘../data/illumina-raw/index.html?C=S;O=A.tmp’
#
# index.html?C=S;O=A. 100%[===================>]   6.59K  --.-KB/s    in 0.001s
#
# 2018-11-14 17:36:04 (5.74 MB/s) - ‘../data/illumina-raw/index.html?C=S;O=A.tmp’ saved [6748/6748]
#
# Removing ../data/illumina-raw/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2018-11-14 17:36:04--  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/?C=D;O=A
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6748 (6.6K) [text/html]
# Saving to: ‘../data/illumina-raw/index.html?C=D;O=A.tmp’
#
# index.html?C=D;O=A. 100%[===================>]   6.59K  --.-KB/s    in 0s
#
# 2018-11-14 17:36:04 (306 MB/s) - ‘../data/illumina-raw/index.html?C=D;O=A.tmp’ saved [6748/6748]
#
# Removing ../data/illumina-raw/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2018-11-14 17:36:04--  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/CP-KS-LibL-L2-G_S34_L006_R1_001.fastq.gz
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 195276148 (186M) [application/x-gzip]
# Saving to: ‘../data/illumina-raw/CP-KS-LibL-L2-G_S34_L006_R1_001.fastq.gz’
#
# CP-KS-LibL-L2-G_S34 100%[===================>] 186.23M  20.1MB/s    in 11s
#
# 2018-11-14 17:36:16 (16.3 MB/s) - ‘../data/illumina-raw/CP-KS-LibL-L2-G_S34_L006_R1_001.fastq.gz’ saved [195276148/195276148]
#
# --2018-11-14 17:36:16--  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/CP-KS-LibL-L3-G_S64_L006_R1_001.fastq.gz
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 299810719 (286M) [application/x-gzip]
# Saving to: ‘../data/illumina-raw/CP-KS-LibL-L3-G_S64_L006_R1_001.fastq.gz’
#
# CP-KS-LibL-L3-G_S64 100%[===================>] 285.92M  19.8MB/s    in 15s
#
# 2018-11-14 17:36:31 (19.4 MB/s) - ‘../data/illumina-raw/CP-KS-LibL-
  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/?C=N;O=A
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6748 (6.6K) [text/html]
# Saving to: ‘../data/illumina-raw/index.html?C=N;O=A.tmp’
#
# index.html?C=N;O=A. 100%[===================>]   6.59K  --.-KB/s    in 0s
#
# 2018-11-14 17:40:01 (495 MB/s) - ‘../data/illumina-raw/index.html?C=N;O=A.tmp’ saved [6748/6748]
#
# Removing ../data/illumina-raw/index.html?C=N;O=A.tmp since it should be rejected.
#
# --2018-11-14 17:40:01--  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/?C=M;O=D
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6748 (6.6K) [text/html]
# Saving to: ‘../data/illumina-raw/index.html?C=M;O=D.tmp’
#
# index.html?C=M;O=D. 100%[===================>]   6.59K  --.-KB/s    in 0s
#
# 2018-11-14 17:40:01 (495 MB/s) - ‘../data/illumina-raw/index.html?C=M;O=D.tmp’ saved [6748/6748]
#
# Removing ../data/illumina-raw/index.html?C=M;O=D.tmp since it should be rejected.
#
# --2018-11-14 17:40:01--  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/?C=S;O=D
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6748 (6.6K) [text/html]
# Saving to: ‘../data/illumina-raw/index.html?C=S;O=D.tmp’
#
# index.html?C=S;O=D. 100%[===================>]   6.59K  --.-KB/s    in 0.001s
#
# 2018-11-14 17:40:01 (7.58 MB/s) - ‘../data/illumina-raw/index.html?C=S;O=D.tmp’ saved [6748/6748]
#
# Removing ../data/illumina-raw/index.html?C=S;O=D.tmp since it should be rejected.
#
# --2018-11-14 17:40:01--  http://owl.fish.washington.edu/wetgenes/20181109_QS_Laura/?C=D;O=D
# Reusing existing connection to owl.fish.washington.edu:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 6748 (6.6K) [text/html]
# Saving to: ‘../data/illumina-raw/index.html?C=D;O=D.tmp’
#
# index.html?C=D;O=D. 100%[===================>]   6.59K  --.-KB/s    in 0s
#
# 2018-11-14 17:40:01 (107 MB/s) - ‘../data/illumina-raw/index.html?C=D;O=D.tmp’ saved [6748/6748]
#
# Removing ../data/illumina-raw/index.html?C=D;O=D.tmp since it should be rejected.
#
# FINISHED --2018-11-14 17:40:01--
# Total wall clock time: 3m 57s
# Downloaded: 33 files, 4.0G in 3m 53s (17.5 MB/s)
# downloaded the following files:
# ../data/illumina-raw/CP-KS-LibL-L10-G_S59_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L11-G_S65_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L13-G_S60_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L14-G_S63_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L15-G_S68_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L19-G_S67_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L2-G_S34_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L21-G_S58_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L23-G_S61_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L24-G_S62_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L29-G_S36_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L3-G_S64_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L32-G_S35_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L33-G_S66_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L34-L_S25_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L35-L_S31_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L37-L_S32_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L39-L_S29_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L41-L_S27_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L44-L_S30_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L45-L_S28_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L47-L_S33_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-L7-G_S57_L006_R1_001.fastq.gz
# ../data/illumina-raw/CP-KS-LibL-SN1016-G_S26_L006_R1_001.fastq.gz

# %% [markdown]
# ### Install tag-seq scripts
# I opted to install these scripts into my bioinformatics directory, where I house these types of programs.

# %%
! git clone https://github.com/z0on/tag-based_RNAseq.git /Applications/bioinformatics/tag-based_RNAseq/
# Out:
# Cloning into '/Applications/bioinformatics/tag-based_RNAseq'...
# remote: Enumerating objects: 163, done.
# remote: Total 163 (delta 0), reused 0 (delta 0), pack-reused 163
# Receiving objects: 100% (163/163), 3.95 MiB | 2.11 MiB/s, done.
# Resolving deltas: 100% (88/88), done.

# %%
# create path variable to blast directory 
tagseq = "/Applications/bioinformatics/tag-based_RNAseq/"

# %%
! gunzip -k ../data/illumina-raw/*.fastq.gz

# %%
! ls ../data/illumina-raw/
# Out:
# CP-KS-LibL-L10-G_S59_L006_R1_001.fastq
# CP-KS-LibL-L10-G_S59_L006_R1_001.fastq.gz
# CP-KS-LibL-L11-G_S65_L006_R1_001.fastq
# CP-KS-LibL-L11-G_S65_L006_R1_001.fastq.gz
# CP-KS-LibL-L13-G_S60_L006_R1_001.fastq
# CP-KS-LibL-L13-G_S60_L006_R1_001.fastq.gz
# CP-KS-LibL-L14-G_S63_L006_R1_001.fastq
# CP-KS-LibL-L14-G_S63_L006_R1_001.fastq.gz
# CP-KS-LibL-L15-G_S68_L006_R1_001.fastq
# CP-KS-LibL-L15-G_S68_L006_R1_001.fastq.gz
# CP-KS-LibL-L19-G_S67_L006_R1_001.fastq
# CP-KS-LibL-L19-G_S67_L006_R1_001.fastq.gz
# CP-KS-LibL-L2-G_S34_L006_R1_001.fastq
# CP-KS-LibL-L2-G_S34_L006_R1_001.fastq.gz
# CP-KS-LibL-L21-G_S58_L006_R1_001.fastq
# CP-KS-LibL-L21-G_S58_L006_R1_001.fastq.gz
# CP-KS-LibL-L23-G_S61_L006_R1_001.fastq
# CP-KS-LibL-L23-G_S61_L006_R1_001.fastq.gz
# CP-KS-LibL-L24-G_S62_L006_R1_001.fastq
# CP-KS-LibL-L24-G_S62_L006_R1_001.fastq.gz
# CP-KS-LibL-L29-G_S36_L006_R1_001.fastq
# CP-KS-LibL-L29-G_S36_L006_R1_001.fastq.gz
# CP-KS-LibL-L3-G_S64_L006_R1_001.fastq
# CP-KS-LibL-L3-G_S64_L006_R1_001.fastq.gz
# CP-KS-LibL-L32-G_S35_L006_R1_001.fastq
# CP-KS-LibL-L32-G_S35_L006_R1_001.fastq.gz
# CP-KS-LibL-L33-G_S66_L006_R1_001.fastq
# CP-KS-LibL-L33-G_S66_L006_R1_001.fastq.gz
# CP-KS-LibL-L34-L_S25_L006_R1_001.fastq
# CP-KS-LibL-L34-L_S25_L006_R1_001.fastq.gz
# CP-KS-LibL-L35-L_S31_L006_R1_001.fastq
# CP-KS-LibL-L35-L_S31_L006_R1_001.fastq.gz
# CP-KS-LibL-L37-L_S32_L006_R1_001.fastq
# CP-KS-LibL-L37-L_S32_L006_R1_001.fastq.gz
# CP-KS-LibL-L39-L_S29_L006_R1_001.fastq
# CP-KS-LibL-L39-L_S29_L006_R1_001.fastq.gz
# CP-KS-LibL-L41-L_S27_L006_R1_001.fastq
# CP-KS-LibL-L41-L_S27_L006_R1_001.fastq.gz
# CP-KS-LibL-L44-L_S30_L006_R1_001.fastq
# CP-KS-LibL-L44-L_S30_L006_R1_001.fastq.gz
# CP-KS-LibL-L45-L_S28_L006_R1_001.fastq
# CP-KS-LibL-L45-L_S28_L006_R1_001.fastq.gz
# CP-KS-LibL-L47-L_S33_L006_R1_001.fastq
# CP-KS-LibL-L47-L_S33_L006_R1_001.fastq.gz
# CP-KS-LibL-L7-G_S57_L006_R1_001.fastq
# CP-KS-LibL-L7-G_S57_L006_R1_001.fastq.gz
# CP-KS-LibL-SN1016-G_S26_L006_R1_001.fastq
# CP-KS-LibL-SN1016-G_S26_L006_R1_001.fastq.gz
# quatseq-files.txt

# %%
! rm ../data/illumina-raw/*.gz

# %%
! ls ../data/illumina-raw/
# Out:
# CP-KS-LibL-L10-G_S59_L006_R1_001.fastq
# CP-KS-LibL-L11-G_S65_L006_R1_001.fastq
# CP-KS-LibL-L13-G_S60_L006_R1_001.fastq
# CP-KS-LibL-L14-G_S63_L006_R1_001.fastq
# CP-KS-LibL-L15-G_S68_L006_R1_001.fastq
# CP-KS-LibL-L19-G_S67_L006_R1_001.fastq
# CP-KS-LibL-L2-G_S34_L006_R1_001.fastq
# CP-KS-LibL-L21-G_S58_L006_R1_001.fastq
# CP-KS-LibL-L23-G_S61_L006_R1_001.fastq
# CP-KS-LibL-L24-G_S62_L006_R1_001.fastq
# CP-KS-LibL-L29-G_S36_L006_R1_001.fastq
# CP-KS-LibL-L3-G_S64_L006_R1_001.fastq
# CP-KS-LibL-L32-G_S35_L006_R1_001.fastq
# CP-KS-LibL-L33-G_S66_L006_R1_001.fastq
# CP-KS-LibL-L34-L_S25_L006_R1_001.fastq
# CP-KS-LibL-L35-L_S31_L006_R1_001.fastq
# CP-KS-LibL-L37-L_S32_L006_R1_001.fastq
# CP-KS-LibL-L39-L_S29_L006_R1_001.fastq
# CP-KS-LibL-L41-L_S27_L006_R1_001.fastq
# CP-KS-LibL-L44-L_S30_L006_R1_001.fastq
# CP-KS-LibL-L45-L_S28_L006_R1_001.fastq
# CP-KS-LibL-L47-L_S33_L006_R1_001.fastq
# CP-KS-LibL-L7-G_S57_L006_R1_001.fastq
# CP-KS-LibL-SN1016-G_S26_L006_R1_001.fastq
# quatseq-files.txt

# %% [markdown]
# ### Adaptor trimming, deduplicating, and quality filtering:
# Creating and launching the cleaning process for all files in the same time:

# %%
cd ../data/illumina-raw/
# Out:
# [Errno 2] No such file or directory: '../data/illumina-raw/'
# /Users/laura/Documents/roberts-lab/laura-quantseq/data/illumina-raw

# %%
! ls {tagseq}
# Out:
# 2bRAD_bowtie2_launch.pl        p5barcodes_order.xlsx
# README.md                      picogreen.R
# RNASeq_sample_prep_dec2017.pdf picogreen.csv
# TagSeq_GSAF_Price.xlsx         rnaseq_clipper.pl
# TagSeq_sample_prep_dec2017.pdf rnaseq_clipper0.pl
# TagSeq_sample_prep_may2018.pdf rnaseq_clipper_fasta.pl
# countreads.pl                  rnaseq_clipper_old.pl
# dna.mixing.R                   samcount.pl
# dupCount.R                     samcount_launch.pl
# expression_compiler.pl         samcount_launch_bt2.pl
# iRNAseq_bowtie2map.pl          samcount_v.0.1.pl
# iRNAseq_shrimpmap_SAM.pl       selectFastaByHeader.pl
# iRNAseq_trim_launch.pl         splitFastaByHeader.pl
# iRNAseq_trim_launch0.pl        tag-seq_scripts_manual.pdf
# iRNAseq_trim_launch_bgi.pl     tagSeq_processing_README.txt
# illumina_mix_data.csv          tagseq_bowtie2map.pl
# isogroup_namer.pl              tagseq_clipper.pl
# launcher_creator.py            tagseq_oligo_order.xls
# mix_illumina_qpcr.R            tagseq_trim_launch.pl
# ngs_concat.pl                  tagseq_trim_launch_bgi.pl

# %%
! cat {tagseq}tagseq_trim_launch.pl
# Out:
# #!/usr/bin/perl
#
# my $usage= "
#
# tagseq_trim_launch.pl :
#
# Prints out a series of commands to trim Illumina tag-seq reads, one for each reads file
# (tagseq_clipper.pl | fasx_clipper | fastx_quality_filter )
#
# prints to STDOUT
#
# Arguments:
# 1: glob to fastq files
# 2: optional, the position of name-deriving string in the file name
# 	if separated by underscores,
# 	such as: input file Sample_RNA_2DVH_L002_R1.cat.fastq
# 	specifying arg2 as '3' would create output file with a name '2DVH.fastq'
#
# Example:
# tagseq_trim_launch.pl '\.fq$' > clean
#
# NOTE: use this script if your qualities in the fastq files are 33-based;
# if not, use tagseq_trim_launch_bgi.pl instead
#
# ";
#
# if (!$ARGV[0]) { die $usage;}
# my $glob=$ARGV[0];
#
# opendir THIS, ".";
# my @fqs=grep /$glob/,readdir THIS;
# my $outname="";
#
# foreach $fqf (@fqs) {
# 	if ($ARGV[1]) {
# 		my @parts=split('_',$fqf);
# 		$outname=$parts[$ARGV[1]-1].".trim";
# 	}
# 	else { $outname=$fqf.".trim";}
# 	print "tagseq_clipper.pl $fqf | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >$outname\n";
# }

# %%
! {tagseq}tagseq_trim_launch.pl '\.fastq$' > clean

# %%
ls
# Out:
# CP-KS-LibL-L10-G_S59_L006_R1_001.fastq
# CP-KS-LibL-L11-G_S65_L006_R1_001.fastq
# CP-KS-LibL-L13-G_S60_L006_R1_001.fastq
# CP-KS-LibL-L14-G_S63_L006_R1_001.fastq
# CP-KS-LibL-L15-G_S68_L006_R1_001.fastq
# CP-KS-LibL-L19-G_S67_L006_R1_001.fastq
# CP-KS-LibL-L2-G_S34_L006_R1_001.fastq
# CP-KS-LibL-L21-G_S58_L006_R1_001.fastq
# CP-KS-LibL-L23-G_S61_L006_R1_001.fastq
# CP-KS-LibL-L24-G_S62_L006_R1_001.fastq
# CP-KS-LibL-L29-G_S36_L006_R1_001.fastq
# CP-KS-LibL-L3-G_S64_L006_R1_001.fastq
# CP-KS-LibL-L32-G_S35_L006_R1_001.fastq
# CP-KS-LibL-L33-G_S66_L006_R1_001.fastq
# CP-KS-LibL-L34-L_S25_L006_R1_001.fastq
# CP-KS-LibL-L35-L_S31_L006_R1_001.fastq
# CP-KS-LibL-L37-L_S32_L006_R1_001.fastq
# CP-KS-LibL-L39-L_S29_L006_R1_001.fastq
# CP-KS-LibL-L41-L_S27_L006_R1_001.fastq
# CP-KS-LibL-L44-L_S30_L006_R1_001.fastq
# CP-KS-LibL-L45-L_S28_L006_R1_001.fastq
# CP-KS-LibL-L47-L_S33_L006_R1_001.fastq
# CP-KS-LibL-L7-G_S57_L006_R1_001.fastq
# CP-KS-LibL-SN1016-G_S26_L006_R1_001.fastq
# clean
# quatseq-files.txt

# %%
! head clean
# Out:
# tagseq_clipper.pl CP-KS-LibL-L21-G_S58_L006_R1_001.fastq | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >CP-KS-LibL-L21-G_S58_L006_R1_001.fastq.trim
# tagseq_clipper.pl CP-KS-LibL-L23-G_S61_L006_R1_001.fastq | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >CP-KS-LibL-L23-G_S61_L006_R1_001.fastq.trim
# tagseq_clipper.pl CP-KS-LibL-L34-L_S25_L006_R1_001.fastq | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >CP-KS-LibL-L34-L_S25_L006_R1_001.fastq.trim
# tagseq_clipper.pl CP-KS-LibL-SN1016-G_S26_L006_R1_001.fastq | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >CP-KS-LibL-SN1016-G_S26_L006_R1_001.fastq.trim
# tagseq_clipper.pl CP-KS-LibL-L10-G_S59_L006_R1_001.fastq | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >CP-KS-LibL-L10-G_S59_L006_R1_001.fastq.trim
# tagseq_clipper.pl CP-KS-LibL-L39-L_S29_L006_R1_001.fastq | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >CP-KS-LibL-L39-L_S29_L006_R1_001.fastq.trim
# tagseq_clipper.pl CP-KS-LibL-L33-G_S66_L006_R1_001.fastq | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >CP-KS-LibL-L33-G_S66_L006_R1_001.fastq.trim
# tagseq_clipper.pl CP-KS-LibL-L3-G_S64_L006_R1_001.fastq | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >CP-KS-LibL-L3-G_S64_L006_R1_001.fastq.trim
# tagseq_clipper.pl CP-KS-LibL-L24-G_S62_L006_R1_001.fastq | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >CP-KS-LibL-L24-G_S62_L006_R1_001.fastq.trim
# tagseq_clipper.pl CP-KS-LibL-L11-G_S65_L006_R1_001.fastq | fastx_clipper -a AAAAAAAA -l 20 -Q33 | fastx_clipper -a AGATCGGAAG -l 20 -Q33 | fastq_quality_filter -Q33 -q 20 -p 90 >CP-KS-LibL-L11-G_S65_L006_R1_001.fastq.trim

# %% [markdown]
# ### now execute all commands written to file 'clean', preferably in parallel
